# %% [markdown]
# <a href="https://colab.research.google.com/github/Masiania-bit/test/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world

# %%
# Out:
# [5, 5, 5, 5, 5, 5, 5]
